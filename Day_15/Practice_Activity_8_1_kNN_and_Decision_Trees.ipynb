# %%
# !pip install palmerpenguins
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.compose import make_column_selector, ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
import pandas as pd
import numpy as np
from palmerpenguins import load_penguins

# %% [markdown]
# # Palmer Penguins Modeling
#
# Import the Palmer Penguins dataset and print out the first few rows.
#
# Suppose we want to predict `bill_depth_mm` using the other variables in the dataset.
#
# **Dummify** all variables that require this.

# %%
penguins = load_penguins()
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins = penguins.dropna()
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# Let's use the other variables to predict `bill_depth_mm`. Prepare your data and fit the following models on the entire dataset:
#
# * Your best multiple linear regression model from before
# * Two kNN models (for different values of K)
# * A decision tree model

# %%
X = penguins.drop(["bill_depth_mm"], axis = 1)
y = penguins["bill_depth_mm"]

X_train, X_test, y_train, y_test = train_test_split(X,y)

Column_Transformer = ColumnTransformer(
  [
    ("dummify",
    OneHotEncoder(sparse_output = False, handle_unknown = "ignore"),
    make_column_selector(dtype_include = object)),
    ("standardize",
    StandardScaler(),
    make_column_selector(dtype_include = np.number))
  ],
  remainder = "passthrough"
).set_output(transform = "pandas")

X_train = Column_Transformer.fit_transform(X_train)
X_test = Column_Transformer.fit_transform(X_test)

# %% [markdown]
# Create a plot like the right plot of Fig 1. in our Model Validation chapter with the training and test error plotted for each of your four models.
#
# Which of your models was best?

# %%
Elastic_Net = ElasticNet(alpha = 0.001, l1_ratio = 0.5)

fitted = Elastic_Net.fit(X_train,y_train)

predict1 = fitted.predict(X_test)

MSE1 = mean_squared_error(y_test, predict1)

print(MSE1)

predict11 = fitted.predict(X_train)

MSE11 = mean_squared_error(y_train, predict11)

print(MSE11)
# Out:
# 0.5481177471071038
# 0.6230651492414976

# %%
K_Neighbors = KNeighborsRegressor(n_neighbors = 3)

fitted = K_Neighbors.fit(X_train,y_train)

predict211 = fitted.predict(X_test)

MSE211 = mean_squared_error(y_test, predict211)

print(MSE211)

predict212 = fitted.predict(X_train)

MSE212 = mean_squared_error(y_train, predict212)

print(MSE212)
# Out:
# 0.6194708994708995
# 0.3912583668005355

# %%
K_Neighbors = KNeighborsRegressor(n_neighbors = 6)

fitted = K_Neighbors.fit(X_train,y_train)

predict221 = fitted.predict(X_test)

MSE221 = mean_squared_error(y_test, predict221)

print(MSE221)

predict222 = fitted.predict(X_train)

MSE222 = mean_squared_error(y_train, predict222)

print(MSE222)
# Out:
# 0.6356911375661382
# 0.4892179830432842

# %%
K_Neighbors = KNeighborsRegressor(n_neighbors = 12)

fitted = K_Neighbors.fit(X_train,y_train)

predict231 = fitted.predict(X_test)

MSE231 = mean_squared_error(y_test, predict231)

print(MSE231)

predict232 = fitted.predict(X_train)

MSE232 = mean_squared_error(y_train, predict232)

print(MSE232)
# Out:
# 0.6042964616402127
# 0.5612594823739401

# %%
K_Neighbors = KNeighborsRegressor(n_neighbors = 24)

fitted = K_Neighbors.fit(X_train,y_train)

predict241 = fitted.predict(X_test)

MSE241 = mean_squared_error(y_test, predict241)

print(MSE241)

predict242 = fitted.predict(X_train)

MSE242 = mean_squared_error(y_train, predict242)

print(MSE242)
# Out:
# 0.5900347222222222
# 0.630781598616689

# %%
Decision_Tree = DecisionTreeRegressor(max_depth = 1)

fitted = Decision_Tree.fit(X_train,y_train)

predict = fitted.predict(X_test)

MSE311 = mean_squared_error(y_test, predict)

print(MSE311)

predict = fitted.predict(X_train)

MSE312 = mean_squared_error(y_train, predict)

print(MSE312)
# Out:
# 1.2424351796169186
# 1.2555874098804856

# %%
Decision_Tree = DecisionTreeRegressor(max_depth = 2)

fitted = Decision_Tree.fit(X_train,y_train)

predict = fitted.predict(X_test)

MSE321 = mean_squared_error(y_test, predict)

print(MSE321)

predict = fitted.predict(X_train)

MSE322 = mean_squared_error(y_train, predict)

print(MSE322)
# Out:
# 0.6706708245676108
# 0.692367658788464

# %%
Decision_Tree = DecisionTreeRegressor(max_depth = 4)

fitted = Decision_Tree.fit(X_train,y_train)

predict = fitted.predict(X_test)

MSE331 = mean_squared_error(y_test, predict)

print(MSE331)

predict = fitted.predict(X_train)

MSE332 = mean_squared_error(y_train, predict)

print(MSE332)
# Out:
# 0.6639841153963402
# 0.5141218373903126

# %%
Decision_Tree = DecisionTreeRegressor(max_depth = 8)

fitted = Decision_Tree.fit(X_train,y_train)

predict = fitted.predict(X_test)

MSE341 = mean_squared_error(y_test, predict)

print(MSE341)

predict = fitted.predict(X_train)

MSE342 = mean_squared_error(y_train, predict)

print(MSE342)
# Out:
# 1.0811069085858795
# 0.18978997167809558

# %% [markdown]
# Are any of the models above underfitting the data? If so, which ones and how can you tell?
#
# Are any of the models above overfitting the data? If so, which ones and how can you tell?
#
# Which of the above models do you think fits the data best and why?

# %% [markdown]
# - Underfitting: None of the models show clear signs of underfitting, as none have high error rates or low accuracy on both training and validation datasets.
#
# - Overfitting: The models with pairs (0.3891253904506918, 0.7645403439153446), (0.45292057117358303, 0.7503976521164022), and (0.4566256607441346, 1.3040144173525439) are overfitting because they perform well on training data but poorly on validation data, indicating they're capturing noise instead of underlying patterns.
#
# - Best Fit: The pair (0.5006411758143685, 0.7907302000661379) might be the best fit, as it shows a reasonable balance between training and validation performance, suggesting good generalization without significant overfitting.
